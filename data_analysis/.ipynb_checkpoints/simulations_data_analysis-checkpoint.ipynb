# %% [markdown]
# # Simulations Data Analysis

# %% [markdown]
# ### Extract the simulation results

# %%
import pandas as pd

# %%
metrics_df = pd.read_csv('../raw_data/phase1_results.csv',header=0,skiprows = 6, nrows = 10, usecols =[0,1])
metrics_df
# Out:
#                   [run number]       1
# 0       average-susceptibility    60.0
# 1        average-recovery-time   504.0
# 2           initial-population  5000.0
# 3             initial-infected     1.0
# 4           average-death-rate     0.2
# 5        average-recovery-rate    90.0
# 6             quarantine-delay     1.0
# 7       mass-testing-intensity     0.0
# 8  social-distancing-intensity     0.0
# 9           lockdown-intensity     0.0

# %%
sim_df = pd.read_csv('../raw_data/phase1_results.csv',header=0,skiprows = 24, nrows = 1564, usecols =[1,2,3,4,5,6,7,8,9])
sim_df
# Out:
#       count turtles  \
# 0              5000
# 1              5000
# 2              5000
# 3              5000
# 4              5000
# 5              5000
# 6              5000
# 7              5000
# 8              5000
# 9              5000
# 10             5000
# 11             5000
# 12             5000
# 13             5000
# 14             5000
# 15             5000
# 16             5000
# 17             5000
# 18             5000
# 19             5000
# 20             5000
# 21             5000
# 22             5000
# 23             5000
# 24             5000
# 25             5000
# 26             5000
# 27             5000
# 28             5000
# 29             5000
# ...             ...
# 1534           1931
# 1535           1931
# 1536           1931
# 1537           1931
# 1538           1931
# 1539           1931
# 1540           1931
# 1541           1931
# 1542           1931
# 1543           1931
# 1544           1931
# 1545           1931
# 1546           1931
# ...
